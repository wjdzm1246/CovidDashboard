# %%
import pandas as pd

df = pd.read_csv("data/time_confirmed.csv")
df = df.sum()
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       1 import pandas as pd
#       3 df = pd.read_csv("data/time_confirmed.csv")
# ----> 4 df = df.sum()
#       5 df
#
# File ~/.virtualenvs/ronacorona/lib/python3.12/site-packages/pandas/core/frame.py:11670, in DataFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   11661 @doc(make_doc("sum", ndim=2))
#   11662 def sum(
#   11663     self,
#    (...)
#   11668     **kwargs,
#   11669 ):
# > 11670     result = super().sum(axis, skipna, numeric_only, min_count, **kwargs)
#   11671     return result.__finalize__(self, method="sum")
#
# File ~/.virtualenvs/ronacorona/lib/python3.12/site-packages/pandas/core/generic.py:12506, in NDFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   12498 def sum(
#   12499     self,
#   12500     axis: Axis | None = 0,
#    (...)
# ...
